# %% [markdown]
# # Time Series Forecasting Models (Neighborhood-Level)
#
# Building and comparing Prophet forecasts for Boston 311 service request demand at the neighborhood level.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from prophet import Prophet

warnings.filterwarnings('ignore')

raw_df = pd.read_parquet('../data/processed/daily_by_neighborhood.parquet')
raw_df['date'] = pd.to_datetime(raw_df['date'])

value_cols = [col for col in raw_df.columns if col != 'date']
df = raw_df.melt(id_vars='date', value_vars=value_cols, var_name='neighborhood', value_name='count')

df['neighborhood'] = df['neighborhood'].astype(str).str.strip()
df = df[df['neighborhood'] != '']
df['count'] = pd.to_numeric(df['count'], errors='coerce').fillna(0.0)

df['year'] = df['date'].dt.year

df = df.sort_values(['neighborhood', 'date']).reset_index(drop=True)

print('Data shape:', df.shape)
print('Date range:', df['date'].min(), 'to', df['date'].max())
print('Neighborhoods:', df['neighborhood'].nunique())
print('Years covered:', sorted(df['year'].unique()))
print('\nColumns:', df.columns.tolist())
df.head()
# Out:
# Data shape: (52608, 4)
# Date range: 2019-01-01 00:00:00 to 2024-12-31 00:00:00
# Neighborhoods: 24
# Years covered: [2019, 2020, 2021, 2022, 2023, 2024]
#
# Columns: ['date', 'neighborhood', 'count', 'year']
#         date neighborhood  count  year
# 0 2019-01-01      Allston      0  2019
# 1 2019-01-02      Allston      3  2019
# 2 2019-01-03      Allston      2  2019
# 3 2019-01-04      Allston      1  2019
# 4 2019-01-05      Allston      2  2019

# %%
neighborhood_totals = (
    df.groupby('neighborhood', as_index=False)['count']
    .sum()
    .sort_values('count', ascending=False)
)

print('\nTop neighborhoods by total requests:')
display(neighborhood_totals.head(10))

top_neighborhoods = neighborhood_totals.head(6)['neighborhood'].tolist()
plot_df = df[df['neighborhood'].isin(top_neighborhoods)]

plt.figure(figsize=(15, 7))
sns.lineplot(data=plot_df, x='date', y='count', hue='neighborhood', linewidth=1)
plt.title('Daily 311 Request Volume (Top 6 Neighborhoods)', fontsize=14, fontweight='bold')
plt.xlabel('Date')
plt.ylabel('Number of Requests')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Top neighborhoods by total requests:
#                               neighborhood   count
# 7                               Dorchester  227247
# 18                                 Roxbury  142341
# 20  South Boston / South Boston Waterfront  134253
# 1                       Allston / Brighton  115919
# 21                               South End  108938
# 9                              East Boston  108558
# 13                           Jamaica Plain   92683
# 8            Downtown / Financial District   90021
# 2                                 Back Bay   79067
# 12                               Hyde Park   64683

# %% [markdown]
# ## Per-Neighborhood Train/Test Split
#
# Train: years < 2024 | Test: year == 2024

# %%
train = df[df['year'] < 2024].copy()
test = df[df['year'] == 2024].copy()

train_neighborhoods = set(train['neighborhood'].unique())
test_neighborhoods = set(test['neighborhood'].unique())
valid_neighborhoods = sorted(train_neighborhoods & test_neighborhoods)

train = train[train['neighborhood'].isin(valid_neighborhoods)].copy()
test = test[test['neighborhood'].isin(valid_neighborhoods)].copy()

df_model = df[df['neighborhood'].isin(valid_neighborhoods)].copy()

print('Neighborhoods modeled:', len(valid_neighborhoods))
print('Train rows (years < 2024):', len(train))
print('Test rows (year == 2024):', len(test))

check = test.groupby('neighborhood').size().describe()
print('\nTest rows per neighborhood:')
print(check)

sample_n = valid_neighborhoods[0]
train_sample = train[train['neighborhood'] == sample_n]
test_sample = test[test['neighborhood'] == sample_n]

plt.figure(figsize=(15, 5))
plt.plot(
    train_sample['date'],
    train_sample['count'],
    label=f'{sample_n} Train (years < 2024)',
    linewidth=1,
)
plt.plot(
    test_sample['date'],
    test_sample['count'],
    label=f'{sample_n} Test (year == 2024)',
    linewidth=1,
    color='orange',
)
plt.title(f'Train/Test Split Example: {sample_n}', fontsize=13, fontweight='bold')
plt.xlabel('Date')
plt.ylabel('Number of Requests')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Neighborhoods modeled: 24
# Train rows (years < 2024): 43824
# Test rows (year == 2024): 8784
#
# Test rows per neighborhood:
# count     24.0
# mean     366.0
# std        0.0
# min      366.0
# 25%      366.0
# 50%      366.0
# 75%      366.0
# max      366.0
# dtype: float64

# %%
def mape_safe(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    denom = np.where(y_true == 0, 1, y_true)
    return np.mean(np.abs((y_true - y_pred) / denom)) * 100

all_predictions = []
metrics_rows = []
models = {}

for i, n in enumerate(valid_neighborhoods, start=1):
    train_n = train[train['neighborhood'] == n][['date', 'count']].rename(columns={'date': 'ds', 'count': 'y'})
    test_n = test[test['neighborhood'] == n][['date', 'count']].rename(columns={'date': 'ds', 'count': 'y'})

    model = Prophet(
        daily_seasonality=False,
        weekly_seasonality=True,
        yearly_seasonality=True,
        changepoint_prior_scale=0.05,
    )
    model.fit(train_n)

    future = model.make_future_dataframe(periods=len(test_n), freq='D', include_history=True)
    forecast = model.predict(future).tail(len(test_n))[['ds', 'yhat']]
    forecast['yhat'] = np.maximum(0.0, forecast['yhat'])

    y_true = test_n['y'].to_numpy(dtype=float)
    y_pred = forecast['yhat'].to_numpy(dtype=float)

    metrics_rows.append({
        'neighborhood': n,
        'MAE': mean_absolute_error(y_true, y_pred),
        'RMSE': np.sqrt(mean_squared_error(y_true, y_pred)),
        'MAPE': mape_safe(y_true, y_pred),
        'R2': r2_score(y_true, y_pred),
        'test_mean': float(np.mean(y_true)),
        'nMAE_%': (mean_absolute_error(y_true, y_pred) / max(np.mean(y_true), 1e-9)) * 100,
    })

    preds_n = test_n[['ds']].copy()
    preds_n['neighborhood'] = n
    preds_n['y_true'] = y_true
    preds_n['y_pred'] = y_pred
    all_predictions.append(preds_n)
    models[n] = model

    if i % 5 == 0 or i == len(valid_neighborhoods):
        print(f'Completed {i}/{len(valid_neighborhoods)} neighborhoods')

predictions_df = pd.concat(all_predictions, ignore_index=True)
metrics_df = pd.DataFrame(metrics_rows).sort_values('RMSE').reset_index(drop=True)

print('\nPer-neighborhood Prophet performance (top 10 by RMSE):')
display(metrics_df.head(10))

macro_avg = metrics_df[['MAE', 'RMSE', 'MAPE', 'R2', 'nMAE_%']].mean()
macro_std = metrics_df[['MAE', 'RMSE', 'MAPE', 'R2', 'nMAE_%']].std()

macro_summary = pd.DataFrame({
    'metric': ['MAE', 'RMSE', 'MAPE', 'R2', 'nMAE_%'],
    'avg_across_neighborhoods': [
        macro_avg['MAE'],
        macro_avg['RMSE'],
        macro_avg['MAPE'],
        macro_avg['R2'],
        macro_avg['nMAE_%'],
    ],
    'std_across_neighborhoods': [
        macro_std['MAE'],
        macro_std['RMSE'],
        macro_std['MAPE'],
        macro_std['R2'],
        macro_std['nMAE_%'],
    ],
})

print('\nPrimary evaluation (macro average over neighborhoods):')
display(macro_summary)

overall_mae = mean_absolute_error(predictions_df['y_true'], predictions_df['y_pred'])
overall_rmse = np.sqrt(mean_squared_error(predictions_df['y_true'], predictions_df['y_pred']))
overall_r2 = r2_score(predictions_df['y_true'], predictions_df['y_pred'])

print('\nSecondary pooled metrics (all neighborhood-days combined):')
print('MAE:', round(overall_mae, 4))
print('RMSE:', round(overall_rmse, 4))
print('R²:', round(overall_r2, 4))
# Out:
# 22:24:55 - cmdstanpy - INFO - Chain [1] start processing
# 22:24:56 - cmdstanpy - INFO - Chain [1] done processing
# 22:24:56 - cmdstanpy - INFO - Chain [1] start processing
# 22:24:56 - cmdstanpy - INFO - Chain [1] done processing
# 22:24:56 - cmdstanpy - INFO - Chain [1] start processing
# 22:24:57 - cmdstanpy - INFO - Chain [1] done processing
# 22:24:57 - cmdstanpy - INFO - Chain [1] start processing
# 22:24:57 - cmdstanpy - INFO - Chain [1] done processing
# 22:24:57 - cmdstanpy - INFO - Chain [1] start processing
# 22:24:58 - cmdstanpy - INFO - Chain [1] done processing
# 22:24:58 - cmdstanpy - INFO - Chain [1] start processing
# 22:24:58 - cmdstanpy - INFO - Chain [1] done processing
# Completed 5/24 neighborhoods
# 22:24:58 - cmdstanpy - INFO - Chain [1] start processing
# 22:24:58 - cmdstanpy - INFO - Chain [1] done processing
# 22:24:59 - cmdstanpy - INFO - Chain [1] start processing
# 22:24:59 - cmdstanpy - INFO - Chain [1] done processing
# 22:24:59 - cmdstanpy - INFO - Chain [1] start processing
# 22:24:59 - cmdstanpy - INFO - Chain [1] done processing
# 22:25:00 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:00 - cmdstanpy - INFO - Chain [1] done processing
# 22:25:00 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:00 - cmdstanpy - INFO - Chain [1] done processing
# Completed 10/24 neighborhoods
# 22:25:00 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:01 - cmdstanpy - INFO - Chain [1] done processing
# 22:25:01 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:01 - cmdstanpy - INFO - Chain [1] done processing
# 22:25:01 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:01 - cmdstanpy - INFO - Chain [1] done processing
# 22:25:02 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:02 - cmdstanpy - INFO - Chain [1] done processing
# 22:25:02 - cmdstanpy - INFO - Chain [1] start processing
# Completed 15/24 neighborhoods
# 22:25:02 - cmdstanpy - INFO - Chain [1] done processing
# 22:25:03 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:03 - cmdstanpy - INFO - Chain [1] done processing
# 22:25:03 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:03 - cmdstanpy - INFO - Chain [1] done processing
# 22:25:03 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:03 - cmdstanpy - INFO - Chain [1] done processing
# 22:25:04 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:04 - cmdstanpy - INFO - Chain [1] done processing
# 22:25:04 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:04 - cmdstanpy - INFO - Chain [1] done processing
# Completed 20/24 neighborhoods
# 22:25:05 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:05 - cmdstanpy - INFO - Chain [1] done processing
# 22:25:05 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:05 - cmdstanpy - INFO - Chain [1] done processing
# 22:25:05 - cmdstanpy - INFO - Chain [1] start processing
# 22:25:06 - cmdstanpy - INFO - Chain [1] done processing
# Completed 24/24 neighborhoods
#
# Per-neighborhood Prophet performance (top 10 by RMSE):
#                                    neighborhood       MAE      RMSE  \
# 0                            Other_Neighborhood  0.041291  0.226181
# 1                                       Unknown  0.670916  0.853411
# 2                                      Mattapan  1.358716  1.810807
# 3                                       Allston  1.853175  2.420886
# 4                                      Brighton  2.236202  2.875167
# 5                                  South Boston  2.667205  3.473821
# 6  Fenway / Kenmore / Audubon Circle / Longwood  4.735394  6.816136
# 7                                  Mission Hill  5.470600  8.694101
# 8                                   Charlestown  7.070217  9.229793
# 9                                    Roslindale  6.552178  9.409040
#
#         MAPE        R2  test_mean      nMAE_%
# 0   3.316896 -0.010008   0.035519  116.251348
# 1  53.194222 -0.013383   0.581967  115.284102
# 2  74.658868 -0.014410   1.778689   76.388634
# 3  89.495929  0.127439   3.442623   53.830321
# 4  69.681485  0.160823   5.516393   40.537398
# 5  56.832637  0.173468   7.890710   33.801834
# 6  43.859793  0.256869  14.983607   31.603834
# 7  62.575352  0.409055  13.737705   39.821792
# 8  47.187382  0.348851  24.423497   28.948421
# 9  30.622492  0.291623  25.469945   25.725135
# Primary evaluation (macro average over neighborhoods):
#    metric  avg_across_neighborhoods  std_across_neighborhoods
# 0     MAE                  7.947291                  4.821114
# 1    RMSE                 10.756162                  6.415259
# 2    MAPE                 39.604128                 19.949285
# 3      R2                  0.233831                  0.177602
# 4  nMAE_%                 38.288103                 26.899671
# Secondary pooled metrics (all neighborhood-days combined):
# MAE: 7.9473
# RMSE: 12.4554
# R²: 0.8199

# %%
best_n = metrics_df.iloc[0]['neighborhood']
worst_n = metrics_df.iloc[-1]['neighborhood']

for n in [best_n, worst_n]:
    train_n = train[train['neighborhood'] == n]
    test_n = test[test['neighborhood'] == n]
    pred_n = predictions_df[predictions_df['neighborhood'] == n]

    plt.figure(figsize=(14, 5))
    plt.plot(train_n['date'], train_n['count'], label='Train (years < 2024)', linewidth=1.5)
    plt.plot(test_n['date'], test_n['count'], label='Actual (2024)', linewidth=1.7, color='green')
    plt.plot(pred_n['ds'], pred_n['y_pred'], label='Prophet Forecast', linestyle='--', linewidth=1.7, color='blue')
    plt.axvline(x=test_n['date'].min(), color='gray', linestyle='--', alpha=0.5)
    plt.title(f'Neighborhood Forecast: {n}', fontsize=13, fontweight='bold')
    plt.xlabel('Date')
    plt.ylabel('Number of Requests')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

plt.figure(figsize=(12, 5))
metrics_sorted = metrics_df.sort_values('R2', ascending=False)
plt.bar(metrics_sorted['neighborhood'], metrics_sorted['R2'])
plt.xticks(rotation=75, ha='right')
plt.title('Prophet R² by Neighborhood', fontsize=13, fontweight='bold')
plt.xlabel('Neighborhood')
plt.ylabel('R²')
plt.grid(True, axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
